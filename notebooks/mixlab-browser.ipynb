# %% [markdown]
# # Your mix, your model
#
# Exported from **Mixlab**. This notebook contains your data and the complete model configuration. It is yours to inspect, change, and extend.
#
# - 179 weeks
# - Channels: paid_search, paid_social
# - Controls: event_1, event_2, trend
# - 4 chains × 1000 retained draws
#
# The data remain local until you choose to upload or share this notebook.

# %% [markdown]
# ## Browser-native route
# Open this notebook in notebook.link or any Jupyter environment with IPython. The notebook prepares editable Python source and a local browser lab. PyMC, Numba, and nuts-rs run in the lab’s WebAssembly worker. The notebook kernel only needs Python and IPython.
#
# The browser lab downloads about 120 MB on first use. Its origin must be reachable and, for a private deployment, signed in. If embedding is blocked, use the separate-tab link. Nothing executes until you click **Run model**.

# %%
import json

model_source = json.loads("\"from pathlib import Path\\nimport json\\nimport pandas as pd\\nfrom pymc_marketing.mmm import MMM, GeometricAdstock, LogisticSaturation\\nfrom pymc_extras.prior import Prior\\n\\nconfig = json.loads(\\\"{\\\\\\\"lag\\\\\\\":8,\\\\\\\"seasonality\\\\\\\":true,\\\\\\\"chains\\\\\\\":4,\\\\\\\"tune\\\\\\\":1000,\\\\\\\"draws\\\\\\\":1000,\\\\\\\"targetAccept\\\\\\\":0.95,\\\\\\\"seed\\\\\\\":42,\\\\\\\"priorScale\\\\\\\":2}\\\")\\ndata = pd.read_csv('/mixlab-data.csv', parse_dates=['date'])\\nchannels = [c for c in data.columns if c.startswith('channel_')]\\ncontrols = [c for c in data.columns if c.startswith('control_')]\\n\\nmmm = MMM(\\n    date_column='date',\\n    channel_columns=channels,\\n    control_columns=controls or None,\\n    adstock=GeometricAdstock(l_max=config['lag'], normalize=True),\\n    saturation=LogisticSaturation(\\n        priors={'beta': Prior('HalfNormal', sigma=config['priorScale'])},\\n    ),\\n    yearly_seasonality=2 if config['seasonality'] else None,\\n)\\nmmm.build_model(data.drop(columns='y'), data.y)\\nmodel = mmm._get_sampling_model()\\n\"")
print(model_source)

# %%
csv_text = json.loads("\"date,y,channel_0,channel_1,control_0,control_1,control_2\\n2018-04-02,79693.24,5734.44,0,0,0,0\\n2018-04-09,75257.44,2022.99,0,0,0,1\\n2018-04-16,89339.35,5263.2,0,0,0,2\\n2018-04-23,77284.39,1285.17,0,0,0,3\\n2018-04-30,88832.51,6961.41,0,0,0,4\\n2018-05-07,73547.93,849.08,0,0,0,5\\n2018-05-14,101350.93,7636.48,0,0,0,6\\n2018-05-21,121581.98,6010.56,12316.95,0,0,7\\n2018-05-28,99084.11,4555.27,0,0,0,8\\n2018-06-04,117313.53,16884.98,0,0,0,9\\n2018-06-11,101932.66,7653.69,0,0,0,10\\n2018-06-18,99830.85,6536.57,0,0,0,11\\n2018-06-25,93771.7,7946.9,0,0,0,12\\n2018-07-02,130726.91,7616.01,13498.62,0,0,13\\n2018-07-09,100619.67,5911.06,0,0,0,14\\n2018-07-16,92773.82,16594.93,0,0,0,15\\n2018-07-23,84190.92,5544.28,0,0,0,16\\n2018-07-30,97520.17,16370.73,0,0,0,17\\n2018-08-06,78123.43,4512.58,0,0,0,18\\n2018-08-13,70997.24,4256.52,0,0,0,19\\n2018-08-20,80508.68,7256.48,0,0,0,20\\n2018-08-27,64466.13,2649.2,0,0,0,21\\n2018-09-03,81593.06,6534.74,0,0,0,22\\n2018-09-10,83128.71,2647.2,0,0,0,23\\
0,144\\n2021-01-11,103267.71,3275.57,0,0,0,145\\n2021-01-18,88045.06,2101.45,0,0,0,146\\n2021-01-25,112585.58,5828.04,0,0,0,147\\n2021-02-01,108817.09,7814.21,0,0,0,148\\n2021-02-08,94949.67,1961.78,0,0,0,149\\n2021-02-15,93023.88,2904.37,0,0,0,150\\n2021-02-22,113563.56,16961.8,0,0,0,151\\n2021-03-01,106552.86,1533.66,0,0,0,152\\n2021-03-08,101855.55,5864.75,0,0,0,153\\n2021-03-15,97219.37,3022.44,0,0,0,154\\n2021-03-22,106241.18,6113.2,0,0,0,155\\n2021-03-29,94332.48,4552.23,0,0,0,156\\n2021-04-05,97598.16,1556.74,0,0,0,157\\n2021-04-12,104921.93,6070.09,0,0,0,158\\n2021-04-19,141185.32,3055.73,13063.43,0,0,159\\n2021-04-26,149037.73,7696.89,12814.73,0,0,160\\n2021-05-03,141217.06,16387.82,0,0,0,161\\n2021-05-10,113747.53,2564.41,0,0,0,162\\n2021-05-17,137360.83,3351.85,11909.82,0,0,163\\n2021-05-24,117891.38,5640.68,0,0,0,164\\n2021-05-31,110190.43,7188.11,0,0,0,165\\n2021-06-07,100798.39,2602.52,0,0,0,166\\n2021-06-14,102700.87,2663.55,0,0,0,167\\n2021-06-21,90713.86,1257.18,0,0,0,168\\n2021-06-28,87166.93,3571.88,0,0,0,169\\n2021-07-05,129155.97,6506.79,12724.02,0,0,170\\n2021-07-12,88516.7,4326.07,0,0,0,171\\n2021-07-19,75903.06,726.73,0,0,0,172\\n2021-07-26,63857.59,1214.23,0,0,0,173\\n2021-08-02,71070.92,594.44,0,0,0,174\\n2021-08-09,111310.19,2981.07,12086.88,0,0,175\\n2021-08-16,82753.03,3093.88,0,0,0,176\\n2021-08-23,89580.83,5044.63,0,0,0,177\\n2021-08-30,93519.47,7899.43,0,0,0,178\"")
settings = json.loads("{\"lag\":8,\"seasonality\":true,\"chains\":4,\"tune\":1000,\"draws\":1000,\"targetAccept\":0.95,\"seed\":42,\"priorScale\":2}")
variable_names = json.loads("[\"adstock_alpha\",\"saturation_lam\",\"saturation_beta\",\"y_sigma\",\"intercept_contribution\",\"channel_contribution\",\"gamma_control\",\"gamma_fourier\"]")

# %% [markdown]
# ## Edit freely, then open the lab
# The code cell above contains `model_source` as a string; replace or edit it as needed. Define a PyMC `model`, and update `variable_names` if you change its variables. The lab also has an editable Python cell for continuing with `mmm` and `idata`.

# %%
from IPython.display import IFrame, HTML, display
from urllib.parse import quote
from html import escape

app_url = "https://mixlab-marketing-studio.thomas-wiecki.chatgpt.site"  # Or a self-hosted Mixlab origin.
payload = dict(version=1, source=model_source, csv=csv_text, config=settings, varNames=variable_names)
# A URL fragment is not sent in the HTTP request; do not share this link with private data.
url = app_url.rstrip('/') + '/notebook.html#' + quote(json.dumps(payload), safe='')
display(HTML('<a target="_blank" rel="noopener" href="' + escape(url, quote=True) + '">Open the Python lab in a separate tab</a>'))
display(IFrame(url, width='100%', height=1100))

# %% [markdown]
# ## Take results anywhere
# Download Arrow posterior and sampler-statistic files from the lab. Its follow-up Python cell can inspect `idata`, calculate predictions, or run other analysis in the same browser kernel.
#
# For a native Python session, export the Native PyMC notebook from Mixlab. Both routes use the same model specification, but native PyMC and nuts-rs are different samplers and do not produce identical random draws.
